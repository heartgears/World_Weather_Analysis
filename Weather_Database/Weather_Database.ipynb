# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 751

# %%
# Perform an API call with the OpenWeatherMap.

from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
weather_api_key
# Out:
# '2c947a561585a2648fd2d596ce0e54d9'

# %%
city_weather = requests.get(city_url).json()

city_weather
city_weather["weather"][0]["description"]
# Out:
# 'light rain'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description" : city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | narasannapeta
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | kodinsk
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | cavalcante
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | senj
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | codrington
# Processing Record 12 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 1 | vieste
# Processing Record 14 of Set 1 | tiznit
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | tondano
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | opuwo
# Processing Record 20 of Set 1 | nouakchott
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | north bend
# Processing Record 26 of Set 1 | strelka
# Processing Record 27 of Set 1 | netivot
# Processing Record 28 of Set 1 | cradock
# Processing Record 29 of Set 1 | sitka
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | mackay
# Processing Record 34 of Set 1 | naze
# Processing Record 35 of Set 1 | lagoa
# Processing Record 36 of Set 1 | taltal
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | leirvik
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | ust-nera
# Processing Record 42 of Set 1 | katangli
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | lincoln
# Processing Record 45 of Set 1 | katsuura
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | margate
# Processing Record 48 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | guhagar
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | dingle
# Processing Record 10 of Set 2 | ginda
# Processing Record 11 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | pochutla
# Processing Record 16 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | dongobesh
# Processing Record 21 of Set 2 | umba
# Processing Record 22 of Set 2 | cocorit
# Processing Record 23 of Set 2 | rio grande
# Processing Record 24 of Set 2 | camalu
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | port-cartier
# Processing Record 27 of Set 2 | hrodna
# Processing Record 28 of Set 2 | ostrovnoy
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | san cristobal
# Processing Record 33 of Set 2 | nome
# Processing Record 34 of Set 2 | ewo
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | port blair
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | ban nahin
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | sug-aksy
# City not found. Skipping...
# Processing Record 41 of Set 2 | muleba
# Processing Record 42 of Set 2 | sao joao da barra
# Processing Record 43 of Set 2 | kloulklubed
# Processing Record 44 of Set 2 | grand forks
# Processing Record 45 of Set 2 | ola
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | clyde river
# Processing Record 49 of Set 2 | bathsheba
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | nioro
# Processing Record 2 of Set 3 | cabedelo
# Processing Record 3 of Set 3 | gari
# Processing Record 4 of Set 3 | beroroha
# Processing Record 5 of Set 3 | lata
# Processing Record 6 of Set 3 | astana
# Processing Record 7 of Set 3 | alofi
# Processing Record 8 of Set 3 | itoman
# Processing Record 9 of Set 3 | pakokku
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | mackenzie
# Processing Record 12 of Set 3 | kineshma
# Processing Record 13 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | liuhe
# Processing Record 16 of Set 3 | haines junction
# Processing Record 17 of Set 3 | pitimbu
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | kieta
# Processing Record 20 of Set 3 | hualmay
# Processing Record 21 of Set 3 | flin flon
# Processing Record 22 of Set 3 | kawhia
# Processing Record 23 of Set 3 | pisco
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | hovd
# Processing Record 27 of Set 3 | aksu
# Processing Record 28 of Set 3 | sioux lookout
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | tessalit
# Processing Record 32 of Set 3 | mae sai
# Processing Record 33 of Set 3 | saint anthony
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | zheshart
# Processing Record 36 of Set 3 | necochea
# Processing Record 37 of Set 3 | belmonte
# Processing Record 38 of Set 3 | faya
# Processing Record 39 of Set 3 | okhotsk
# Processing Record 40 of Set 3 | broome
# Processing Record 41 of Set 3 | peterhead
# Processing Record 42 of Set 3 | bundaberg
# Processing Record 43 of Set 3 | jardim
# Processing Record 44 of Set 3 | eyl
# Processing Record 45 of Set 3 | kharp
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | boyabat
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 4 | havre-saint-pierre
# Processing Record 2 of Set 4 | ararat
# Processing Record 3 of Set 4 | bemidji
# Processing Record 4 of Set 4 | gunjur
# Processing Record 5 of Set 4 | hobyo
# Processing Record 6 of Set 4 | saint-jean-port-joli
# Processing Record 7 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 4 | santiago de cao
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | kultuk
# Processing Record 11 of Set 4 | juneau
# Processing Record 12 of Set 4 | tefe
# Processing Record 13 of Set 4 | carnarvon
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | bilma
# Processing Record 16 of Set 4 | ponta do sol
# Processing Record 17 of Set 4 | ko samui
# Processing Record 18 of Set 4 | buraydah
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | labytnangi
# Processing Record 21 of Set 4 | hilo
# Processing Record 22 of Set 4 | mount gambier
# Processing Record 23 of Set 4 | nara
# Processing Record 24 of Set 4 | cockburn town
# Processing Record 25 of Set 4 | ambilobe
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | laurel
# Processing Record 28 of Set 4 | sobolevo
# Processing Record 29 of Set 4 | valdivia
# Processing Record 30 of Set 4 | chipiona
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | itarema
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | hanstholm
# Processing Record 35 of Set 4 | stralsund
# Processing Record 36 of Set 4 | ahipara
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | tulsipur
# Processing Record 39 of Set 4 | puerto maldonado
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | dryden
# Processing Record 42 of Set 4 | anuradhapura
# Processing Record 43 of Set 4 | hamilton
# Processing Record 44 of Set 4 | nelson bay
# Processing Record 45 of Set 4 | chemax
# Processing Record 46 of Set 4 | ukiah
# Processing Record 47 of Set 4 | brainerd
# Processing Record 48 of Set 4 | upernavik
# Processing Record 49 of Set 4 | bezhetsk
# Processing Record 50 of Set 4 | pevek
# Processing Record 1 of Set 5 | batemans bay
# Processing Record 2 of Set 5 | fort-shevchenko
# Processing Record 3 of Set 5 | wajir
# Processing Record 4 of Set 5 | kota bahru
# Processing Record 5 of Set 5 | kirkland lake
# Processing Record 6 of Set 5 | butaritari
# Processing Record 7 of Set 5 | moerai
# Processing Record 8 of Set 5 | athni
# Processing Record 9 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 5 | mayskiy
# Processing Record 11 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 5 | boguchany
# Processing Record 13 of Set 5 | mantena
# Processing Record 14 of Set 5 | yakeshi
# Processing Record 15 of Set 5 | vestmanna
# Processing Record 16 of Set 5 | piacabucu
# Processing Record 17 of Set 5 | kununurra
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | thompson
# Processing Record 20 of Set 5 | kamenka
# Processing Record 21 of Set 5 | alice springs
# Processing Record 22 of Set 5 | ayolas
# Processing Record 23 of Set 5 | westport
# Processing Record 24 of Set 5 | khudumelapye
# Processing Record 25 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 26 of Set 5 | acarau
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | ballitoville
# Processing Record 29 of Set 5 | seara
# Processing Record 30 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 5 | saint-joseph
# Processing Record 35 of Set 5 | vila velha
# Processing Record 36 of Set 5 | masunga
# Processing Record 37 of Set 5 | klaksvik
# Processing Record 38 of Set 5 | caucaia
# Processing Record 39 of Set 5 | zaterechnyy
# Processing Record 40 of Set 5 | jumla
# Processing Record 41 of Set 5 | husavik
# Processing Record 42 of Set 5 | christchurch
# Processing Record 43 of Set 5 | souillac
# Processing Record 44 of Set 5 | inhambane
# Processing Record 45 of Set 5 | yar-sale
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | mehamn
# Processing Record 48 of Set 5 | penalva
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 6 | mar del plata
# Processing Record 2 of Set 6 | ormara
# Processing Record 3 of Set 6 | boende
# Processing Record 4 of Set 6 | ngunguru
# Processing Record 5 of Set 6 | san patricio
# Processing Record 6 of Set 6 | sur
# Processing Record 7 of Set 6 | sambava
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 6 | hirara
# Processing Record 11 of Set 6 | moose factory
# Processing Record 12 of Set 6 | naryan-mar
# Processing Record 13 of Set 6 | taoudenni
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | menges
# Processing Record 16 of Set 6 | blackfoot
# Processing Record 17 of Set 6 | biak
# Processing Record 18 of Set 6 | porlamar
# Processing Record 19 of Set 6 | richards bay
# Processing Record 20 of Set 6 | bahia blanca
# Processing Record 21 of Set 6 | salmas
# Processing Record 22 of Set 6 | puri
# Processing Record 23 of Set 6 | werda
# Processing Record 24 of Set 6 | makakilo city
# Processing Record 25 of Set 6 | dire dawa
# Processing Record 26 of Set 6 | flinders
# Processing Record 27 of Set 6 | alyangula
# Processing Record 28 of Set 6 | bondo
# Processing Record 29 of Set 6 | wokha
# Processing Record 30 of Set 6 | birao
# Processing Record 31 of Set 6 | garmsar
# Processing Record 32 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 6 | gravdal
# Processing Record 34 of Set 6 | pedernales
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | chokurdakh
# Processing Record 37 of Set 6 | apple valley
# Processing Record 38 of Set 6 | torbay
# Processing Record 39 of Set 6 | ribera
# Processing Record 40 of Set 6 | sabzevar
# Processing Record 41 of Set 6 | carbonia
# Processing Record 42 of Set 6 | goderich
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | vardo
# Processing Record 45 of Set 6 | kahului
# Processing Record 46 of Set 6 | black river
# Processing Record 47 of Set 6 | manono
# Processing Record 48 of Set 6 | byron bay
# Processing Record 49 of Set 6 | maningrida
# Processing Record 50 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 7 | chuy
# Processing Record 2 of Set 7 | cayenne
# Processing Record 3 of Set 7 | sao raimundo das mangabeiras
# Processing Record 4 of Set 7 | egvekinot
# Processing Record 5 of Set 7 | madison
# Processing Record 6 of Set 7 | harper
# Processing Record 7 of Set 7 | sattahip
# Processing Record 8 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 7 | warri
# Processing Record 10 of Set 7 | vostok
# Processing Record 11 of Set 7 | hutchinson
# Processing Record 12 of Set 7 | ambagarh chauki
# Processing Record 13 of Set 7 | valentin gomez farias
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 7 | safaga
# Processing Record 17 of Set 7 | diego de almagro
# Processing Record 18 of Set 7 | guiberoua
# Processing Record 19 of Set 7 | henties bay
# Processing Record 20 of Set 7 | korocha
# Processing Record 21 of Set 7 | volot
# Processing Record 22 of Set 7 | erzin
# Processing Record 23 of Set 7 | mayya
# Processing Record 24 of Set 7 | ilulissat
# Processing Record 25 of Set 7 | verkhnevilyuysk
# Processing Record 26 of Set 7 | mumias
# Processing Record 27 of Set 7 | uspenka
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | karratha
# Processing Record 30 of Set 7 | didao
# Processing Record 31 of Set 7 | hurghada
# Processing Record 32 of Set 7 | turka
# Processing Record 33 of Set 7 | vinh long
# Processing Record 34 of Set 7 | sibolga
# Processing Record 35 of Set 7 | santos dumont
# Processing Record 36 of Set 7 | the valley
# Processing Record 37 of Set 7 | newport
# Processing Record 38 of Set 7 | petukhovo
# Processing Record 39 of Set 7 | goksun
# Processing Record 40 of Set 7 | xining
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | pinawa
# Processing Record 43 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 44 of Set 7 | kenai
# Processing Record 45 of Set 7 | namibe
# Processing Record 46 of Set 7 | nainpur
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | caravelas
# Processing Record 49 of Set 7 | mascote
# Processing Record 50 of Set 7 | wampusirpi
# City not found. Skipping...
# Processing Record 1 of Set 8 | norrtalje
# Processing Record 2 of Set 8 | ngaoundere
# Processing Record 3 of Set 8 | saurimo
# Processing Record 4 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 8 | luderitz
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | najran
# Processing Record 8 of Set 8 | vestmannaeyjar
# Processing Record 9 of Set 8 | borama
# City not found. Skipping...
# Processing Record 10 of Set 8 | krasnovishersk
# Processing Record 11 of Set 8 | tecoanapa
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | zaozerne
# Processing Record 14 of Set 8 | olinda
# Processing Record 15 of Set 8 | talaya
# Processing Record 16 of Set 8 | vigrestad
# Processing Record 17 of Set 8 | rocha
# Processing Record 18 of Set 8 | pichayevo
# Processing Record 19 of Set 8 | parma heights
# Processing Record 20 of Set 8 | andradas
# Processing Record 21 of Set 8 | niquelandia
# Processing Record 22 of Set 8 | manta
# Processing Record 23 of Set 8 | maniitsoq
# Processing Record 24 of Set 8 | wanning
# Processing Record 25 of Set 8 | klyuchi
# Processing Record 26 of Set 8 | mus
# Processing Record 27 of Set 8 | teguldet
# Processing Record 28 of Set 8 | lasa
# Processing Record 29 of Set 8 | fenoarivo atsinanana
# Processing Record 30 of Set 8 | lagunas
# Processing Record 31 of Set 8 | portland
# Processing Record 32 of Set 8 | odweyne
# Processing Record 33 of Set 8 | hanyang
# Processing Record 34 of Set 8 | half moon bay
# Processing Record 35 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | vila franca do campo
# Processing Record 38 of Set 8 | krasnaya gorka
# Processing Record 39 of Set 8 | maarianhamina
# Processing Record 40 of Set 8 | kruisfontein
# Processing Record 41 of Set 8 | port macquarie
# Processing Record 42 of Set 8 | ndjole
# Processing Record 43 of Set 8 | pozo colorado
# Processing Record 44 of Set 8 | poum
# Processing Record 45 of Set 8 | wanaka
# Processing Record 46 of Set 8 | waingapu
# Processing Record 47 of Set 8 | talnakh
# Processing Record 48 of Set 8 | lusambo
# Processing Record 49 of Set 8 | paracuru
# Processing Record 50 of Set 8 | coihaique
# Processing Record 1 of Set 9 | wanganui
# Processing Record 2 of Set 9 | jaque
# Processing Record 3 of Set 9 | coari
# Processing Record 4 of Set 9 | leh
# Processing Record 5 of Set 9 | sterling
# Processing Record 6 of Set 9 | caramay
# Processing Record 7 of Set 9 | mulege
# Processing Record 8 of Set 9 | rawson
# Processing Record 9 of Set 9 | bambanglipuro
# Processing Record 10 of Set 9 | kamariotissa
# Processing Record 11 of Set 9 | batticaloa
# Processing Record 12 of Set 9 | stephenville
# Processing Record 13 of Set 9 | ushtobe
# Processing Record 14 of Set 9 | pangai
# Processing Record 15 of Set 9 | rio gallegos
# Processing Record 16 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 9 | tateyama
# Processing Record 18 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | bontang
# Processing Record 21 of Set 9 | fershampenuaz
# Processing Record 22 of Set 9 | san felipe
# Processing Record 23 of Set 9 | uravakonda
# Processing Record 24 of Set 9 | sibu
# Processing Record 25 of Set 9 | aripuana
# Processing Record 26 of Set 9 | nhulunbuy
# Processing Record 27 of Set 9 | port hardy
# Processing Record 28 of Set 9 | kavieng
# Processing Record 29 of Set 9 | scarborough
# Processing Record 30 of Set 9 | ionia
# Processing Record 31 of Set 9 | tam ky
# Processing Record 32 of Set 9 | bac can
# City not found. Skipping...
# Processing Record 33 of Set 9 | gorom-gorom
# Processing Record 34 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 35 of Set 9 | kungurtug
# Processing Record 36 of Set 9 | tendukheda
# Processing Record 37 of Set 9 | mazamet
# Processing Record 38 of Set 9 | campos altos
# Processing Record 39 of Set 9 | okha
# Processing Record 40 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | hammerfest
# Processing Record 42 of Set 9 | quepos
# Processing Record 43 of Set 9 | pontal do parana
# Processing Record 44 of Set 9 | jerantut
# Processing Record 45 of Set 9 | agirish
# Processing Record 46 of Set 9 | alekseyevsk
# Processing Record 47 of Set 9 | winnemucca
# Processing Record 48 of Set 9 | nantucket
# Processing Record 49 of Set 9 | bakchar
# Processing Record 50 of Set 9 | vanimo
# Processing Record 1 of Set 10 | mitsamiouli
# Processing Record 2 of Set 10 | ajra
# Processing Record 3 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 4 of Set 10 | guerrero negro
# Processing Record 5 of Set 10 | corrales
# Processing Record 6 of Set 10 | matagami
# Processing Record 7 of Set 10 | severo-kurilsk
# Processing Record 8 of Set 10 | niederkassel
# Processing Record 9 of Set 10 | nanakuli
# Processing Record 10 of Set 10 | dauphin
# Processing Record 11 of Set 10 | te anau
# Processing Record 12 of Set 10 | geraldton
# Processing Record 13 of Set 10 | qinzhou
# Processing Record 14 of Set 10 | kikwit
# Processing Record 15 of Set 10 | floro
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | teacapan
# Processing Record 18 of Set 10 | epernay
# Processing Record 19 of Set 10 | beringovskiy
# Processing Record 20 of Set 10 | nemuro
# Processing Record 21 of Set 10 | canton
# Processing Record 22 of Set 10 | cabo san lucas
# Processing Record 23 of Set 10 | tougan
# Processing Record 24 of Set 10 | kita
# Processing Record 25 of Set 10 | konjic
# Processing Record 26 of Set 10 | paris
# Processing Record 27 of Set 10 | shetpe
# Processing Record 28 of Set 10 | traralgon
# Processing Record 29 of Set 10 | burica
# City not found. Skipping...
# Processing Record 30 of Set 10 | camana
# Processing Record 31 of Set 10 | lebyazhye
# Processing Record 32 of Set 10 | guilin
# Processing Record 33 of Set 10 | faro
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | lolodorf
# Processing Record 36 of Set 10 | salamiyah
# Processing Record 37 of Set 10 | abu kamal
# Processing Record 38 of Set 10 | barcelos
# Processing Record 39 of Set 10 | arlit
# Processing Record 40 of Set 10 | turukhansk
# Processing Record 41 of Set 10 | zhenlai
# Processing Record 42 of Set 10 | port augusta
# Processing Record 43 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 10 | sobradinho
# Processing Record 45 of Set 10 | butembo
# Processing Record 46 of Set 10 | iquique
# Processing Record 47 of Set 10 | bauchi
# Processing Record 48 of Set 10 | namatanai
# Processing Record 49 of Set 10 | bowen
# Processing Record 50 of Set 10 | rumoi
# Processing Record 1 of Set 11 | salalah
# Processing Record 2 of Set 11 | erzurum
# Processing Record 3 of Set 11 | sinnamary
# Processing Record 4 of Set 11 | masyaf
# Processing Record 5 of Set 11 | el alto
# Processing Record 6 of Set 11 | zhezkazgan
# Processing Record 7 of Set 11 | yatou
# Processing Record 8 of Set 11 | takoradi
# Processing Record 9 of Set 11 | aberdeen
# Processing Record 10 of Set 11 | khorixas
# Processing Record 11 of Set 11 | burtunay
# Processing Record 12 of Set 11 | ajdabiya
# Processing Record 13 of Set 11 | vilaka
# Processing Record 14 of Set 11 | grafton
# Processing Record 15 of Set 11 | sassandra
# Processing Record 16 of Set 11 | marawi
# Processing Record 17 of Set 11 | tsiroanomandidy
# Processing Record 18 of Set 11 | alta floresta
# Processing Record 19 of Set 11 | verkhnetulomskiy
# Processing Record 20 of Set 11 | lorengau
# Processing Record 21 of Set 11 | burns lake
# Processing Record 22 of Set 11 | igurubi
# Processing Record 23 of Set 11 | maraba
# Processing Record 24 of Set 11 | bud
# Processing Record 25 of Set 11 | tual
# Processing Record 26 of Set 11 | san jeronimo
# Processing Record 27 of Set 11 | ouallam
# Processing Record 28 of Set 11 | shirokiy
# Processing Record 29 of Set 11 | dukat
# Processing Record 30 of Set 11 | ode
# Processing Record 31 of Set 11 | srednekolymsk
# Processing Record 32 of Set 11 | ugoofaaru
# Processing Record 33 of Set 11 | hambantota
# Processing Record 34 of Set 11 | moroni
# Processing Record 35 of Set 11 | lumut
# Processing Record 36 of Set 11 | huarmey
# Processing Record 37 of Set 11 | leningradskiy
# Processing Record 38 of Set 11 | kijang
# Processing Record 39 of Set 11 | yumen
# Processing Record 40 of Set 11 | luena
# Processing Record 41 of Set 11 | oranjestad
# Processing Record 42 of Set 11 | wajima
# Processing Record 43 of Set 11 | bennington
# Processing Record 44 of Set 11 | igarka
# Processing Record 45 of Set 11 | gibgos
# Processing Record 46 of Set 11 | ust-koksa
# Processing Record 47 of Set 11 | liberty
# Processing Record 48 of Set 11 | ketchikan
# Processing Record 49 of Set 11 | honiara
# Processing Record 50 of Set 11 | conceicao do araguaia
# Processing Record 1 of Set 12 | awbari
# Processing Record 2 of Set 12 | amalapuram
# Processing Record 3 of Set 12 | pine bluff
# Processing Record 4 of Set 12 | harlingen
# Processing Record 5 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 12 | beasain
# Processing Record 7 of Set 12 | martapura
# Processing Record 8 of Set 12 | hailar
# Processing Record 9 of Set 12 | vagay
# Processing Record 10 of Set 12 | pangnirtung
# Processing Record 11 of Set 12 | kidal
# Processing Record 12 of Set 12 | dakar
# Processing Record 13 of Set 12 | bajna
# Processing Record 14 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | burnie
# Processing Record 16 of Set 12 | livingston
# Processing Record 17 of Set 12 | senador jose porfirio
# Processing Record 18 of Set 12 | ilheus
# Processing Record 19 of Set 12 | pangkalanbuun
# Processing Record 20 of Set 12 | nuuk
# Processing Record 21 of Set 12 | sarangani
# Processing Record 22 of Set 12 | celestun
# Processing Record 23 of Set 12 | perelyub
# Processing Record 24 of Set 12 | aykhal
# Processing Record 25 of Set 12 | atasu
# Processing Record 26 of Set 12 | kavaratti
# Processing Record 27 of Set 12 | semey
# Processing Record 28 of Set 12 | singaraja
# Processing Record 29 of Set 12 | poli
# Processing Record 30 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 31 of Set 12 | araouane
# Processing Record 32 of Set 12 | muli
# Processing Record 33 of Set 12 | port said
# Processing Record 34 of Set 12 | magdagachi
# Processing Record 35 of Set 12 | tanout
# Processing Record 36 of Set 12 | sao francisco
# Processing Record 37 of Set 12 | artyom
# Processing Record 38 of Set 12 | ahuimanu
# Processing Record 39 of Set 12 | topeka
# Processing Record 40 of Set 12 | mount isa
# Processing Record 41 of Set 12 | aguimes
# Processing Record 42 of Set 12 | wilmington
# Processing Record 43 of Set 12 | ipoti
# Processing Record 44 of Set 12 | kashi
# Processing Record 45 of Set 12 | ati
# Processing Record 46 of Set 12 | punta alta
# Processing Record 47 of Set 12 | acapulco
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | hudson bay
# Processing Record 50 of Set 12 | omsukchan
# Processing Record 1 of Set 13 | talen
# Processing Record 2 of Set 13 | pierre
# Processing Record 3 of Set 13 | gorey
# Processing Record 4 of Set 13 | gandajika
# Processing Record 5 of Set 13 | bereda
# Processing Record 6 of Set 13 | saint george
# Processing Record 7 of Set 13 | mwinilunga
# Processing Record 8 of Set 13 | manokwari
# Processing Record 9 of Set 13 | matay
# Processing Record 10 of Set 13 | chancay
# Processing Record 11 of Set 13 | mulchen
# Processing Record 12 of Set 13 | tonekabon
# Processing Record 13 of Set 13 | vaitape
# Processing Record 14 of Set 13 | thinadhoo
# Processing Record 15 of Set 13 | northam
# Processing Record 16 of Set 13 | ullapool
# Processing Record 17 of Set 13 | nonoichi
# Processing Record 18 of Set 13 | tabuk
# Processing Record 19 of Set 13 | kagay
# Processing Record 20 of Set 13 | dehloran
# Processing Record 21 of Set 13 | sisimiut
# Processing Record 22 of Set 13 | centralia
# Processing Record 23 of Set 13 | san carlos de bariloche
# Processing Record 24 of Set 13 | hudiksvall
# Processing Record 25 of Set 13 | norrkoping
# Processing Record 26 of Set 13 | pacific grove
# Processing Record 27 of Set 13 | coos bay
# Processing Record 28 of Set 13 | coachella
# Processing Record 29 of Set 13 | sawakin
# Processing Record 30 of Set 13 | vernashen
# Processing Record 31 of Set 13 | lilongwe
# Processing Record 32 of Set 13 | camacha
# Processing Record 33 of Set 13 | myskhako
# Processing Record 34 of Set 13 | aviles
# Processing Record 35 of Set 13 | marathon
# Processing Record 36 of Set 13 | cove
# Processing Record 37 of Set 13 | khani
# Processing Record 38 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 13 | xuddur
# Processing Record 40 of Set 13 | maumere
# Processing Record 41 of Set 13 | shimoda
# Processing Record 42 of Set 13 | shalinskoye
# Processing Record 43 of Set 13 | mayo
# Processing Record 44 of Set 13 | camocim
# Processing Record 45 of Set 13 | khorramshahr
# Processing Record 46 of Set 13 | daoukro
# Processing Record 47 of Set 13 | sabha
# Processing Record 48 of Set 13 | denpasar
# Processing Record 49 of Set 13 | merauke
# Processing Record 50 of Set 13 | yulara
# Processing Record 1 of Set 14 | nordborg
# Processing Record 2 of Set 14 | south sioux city
# Processing Record 3 of Set 14 | kaeo
# Processing Record 4 of Set 14 | lemesos
# City not found. Skipping...
# Processing Record 5 of Set 14 | calabozo
# Processing Record 6 of Set 14 | neresnytsya
# Processing Record 7 of Set 14 | okato
# Processing Record 8 of Set 14 | tacoronte
# Processing Record 9 of Set 14 | clearwater
# Processing Record 10 of Set 14 | deep river
# Processing Record 11 of Set 14 | ishigaki
# Processing Record 12 of Set 14 | farmington
# Processing Record 13 of Set 14 | nouadhibou
# Processing Record 14 of Set 14 | tehachapi
# Processing Record 15 of Set 14 | vao
# Processing Record 16 of Set 14 | yeppoon
# Processing Record 17 of Set 14 | winneba
# Processing Record 18 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 19 of Set 14 | beloha
# Processing Record 20 of Set 14 | shahrud
# Processing Record 21 of Set 14 | port lincoln
# Processing Record 22 of Set 14 | praia
# Processing Record 23 of Set 14 | arzgir
# Processing Record 24 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 14 | adrar
# Processing Record 26 of Set 14 | altay
# Processing Record 27 of Set 14 | salinopolis
# Processing Record 28 of Set 14 | nicoya
# Processing Record 29 of Set 14 | ixtapa
# Processing Record 30 of Set 14 | dao
# Processing Record 31 of Set 14 | abadan
# Processing Record 32 of Set 14 | dabhol
# Processing Record 33 of Set 14 | warrington
# Processing Record 34 of Set 14 | gwadar
# Processing Record 35 of Set 14 | buala
# Processing Record 36 of Set 14 | jalu
# Processing Record 37 of Set 14 | kumluca
# Processing Record 38 of Set 14 | feijo
# Processing Record 39 of Set 14 | anadyr
# Processing Record 40 of Set 14 | bhatapara
# Processing Record 41 of Set 14 | betki
# City not found. Skipping...
# Processing Record 42 of Set 14 | amapa
# Processing Record 43 of Set 14 | bilibino
# Processing Record 44 of Set 14 | loandjili
# Processing Record 45 of Set 14 | fort nelson
# Processing Record 46 of Set 14 | bahce
# Processing Record 47 of Set 14 | dandong
# Processing Record 48 of Set 14 | manzanillo
# Processing Record 49 of Set 14 | yuzhno-sukhokumsk
# Processing Record 50 of Set 14 | pangody
# Processing Record 1 of Set 15 | cairo
# Processing Record 2 of Set 15 | karasjok
# Processing Record 3 of Set 15 | antalaha
# Processing Record 4 of Set 15 | sinop
# Processing Record 5 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 6 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 7 of Set 15 | deputatskiy
# Processing Record 8 of Set 15 | zaraza
# Processing Record 9 of Set 15 | sungairaya
# Processing Record 10 of Set 15 | belle fourche
# Processing Record 11 of Set 15 | baihar
# Processing Record 12 of Set 15 | horta
# Processing Record 13 of Set 15 | manakara
# Processing Record 14 of Set 15 | price
# Processing Record 15 of Set 15 | santa rosa
# Processing Record 16 of Set 15 | xinzhou
# Processing Record 17 of Set 15 | carballo
# Processing Record 18 of Set 15 | komsomolskiy
# Processing Record 19 of Set 15 | zyryanka
# Processing Record 20 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 21 of Set 15 | gopalpur
# Processing Record 22 of Set 15 | shelui
# Processing Record 23 of Set 15 | zemio
# Processing Record 24 of Set 15 | camopi
# Processing Record 25 of Set 15 | neiafu
# Processing Record 26 of Set 15 | shimizu
# Processing Record 27 of Set 15 | crixas
# Processing Record 28 of Set 15 | porto novo
# Processing Record 29 of Set 15 | abha
# Processing Record 30 of Set 15 | santa fe do sul
# Processing Record 31 of Set 15 | mapiripan
# Processing Record 32 of Set 15 | anloga
# Processing Record 33 of Set 15 | kerema
# Processing Record 34 of Set 15 | kyshtovka
# Processing Record 35 of Set 15 | daru
# Processing Record 36 of Set 15 | havelock
# Processing Record 37 of Set 15 | okakarara
# Processing Record 38 of Set 15 | sorland
# Processing Record 39 of Set 15 | dawlatabad
# Processing Record 40 of Set 15 | nanganga
# Processing Record 41 of Set 15 | southbridge
# Processing Record 42 of Set 15 | road town
# Processing Record 43 of Set 15 | arica
# Processing Record 44 of Set 15 | bayonne
# Processing Record 45 of Set 15 | shirdi
# Processing Record 46 of Set 15 | dibulla
# Processing Record 47 of Set 15 | victor harbor
# Processing Record 48 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 15 | ocos
# Processing Record 50 of Set 15 | sao jose da coroa grande
# Processing Record 1 of Set 16 | andenes
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Narasannapeta  18.4167   84.0500     84.27        74           5
# 1       Hermanus -34.4187   19.2345     60.31        85          69
# 2        Rikitea -23.1203 -134.9692     75.85        76           2
# 3        Kodinsk  58.6881   99.1844     42.71        94           5
# 4    East London -33.0153   27.9116     61.32        83           0
# 5     Cavalcante -13.7975  -47.4583     82.00        31           2
# 6     Kaitangata -46.2817  169.8464     46.53        84          83
# 7           Senj  44.9894   14.9058     74.07        80         100
# 8        Ushuaia -54.8000  -68.3000     40.62        81          20
# 9         Lompoc  34.6391 -120.4579     77.68        65           0
#
#    Wind Speed      Description Country                 Date
# 0        3.71        clear sky      IN  2022-05-22 19:21:32
# 1        7.63    broken clouds      ZA  2022-05-22 19:21:32
# 2       13.69        clear sky      PF  2022-05-22 19:21:33
# 3        1.54        clear sky      RU  2022-05-22 19:22:07
# 4        3.67        clear sky      ZA  2022-05-22 19:23:40
# 5        3.49        clear sky      BR  2022-05-22 19:23:41
# 6       13.11    broken clouds      NZ  2022-05-22 19:23:41
# 7        5.61  overcast clouds      HR  2022-05-22 19:23:41
# 8        5.75       few clouds      AR  2022-05-22 19:21:02
# 9       16.11        clear sky      US  2022-05-22 19:22:06

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
